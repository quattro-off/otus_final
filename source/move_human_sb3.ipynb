# %%
from env.env_simple_move import HumanMoveSimpleAction
import common.mlflow_sb3_helper as mlf

import torch
import numpy as np
from stable_baselines3 import DDPG, SAC, TD3
from stable_baselines3.common.noise import NormalActionNoise

import os

# %%
env = HumanMoveSimpleAction()
mlflow_server = mlf.MLflowServerHelper("http://192.168.0.206:2670")

from pytz import timezone
from datetime import datetime

TZ = timezone('Europe/Moscow')
models = {'DDPG':DDPG, 'SAC':SAC, 'TD3':TD3}
activations = {'ReLU':torch.nn.ReLU, 'Tanh':torch.nn.Tanh}
device = "cuda" if torch.cuda.is_available() else "cpu"

mlflow_path = {}

# %%
exp_params = {
    'env_name': env.name(),
    'algorithm_name': '',
    'exp_id': f'exp_{datetime.now(TZ).strftime("%d%m_%H%M%S")}',
    'seed': 21,
    'net': {
        'activation': 'ReLU',
        'pi': [256, 256],
        'qf': [256, 256],
        'vf': [256, 256],
    },
    'training': {
        'iteration_count': 1,
        'episode_count': 1000,
        'policy': 'MlpPolicy',
        'learning_rate': 0.003,
        'buffer_size': 1000000,
        'learning_starts': 100,
        'batch_size': 256,
        'tau': 0.005,
        'gamma': 0.99,
        'verbose': 0,
        'device': device,
    },
    'validation': {
        'validate_agent_every_n_eps': 600,
        'log_interval': 100
    },
    'evaluation': {
        'episode_count': 1
    }
}

policy_kwargs = dict(activation_fn = activations[exp_params['net']['activation']],
                     net_arch = dict(pi=exp_params['net']['pi'], qf=exp_params['net']['qf'], vf=exp_params['net']['vf']))

exp_name = 'env_' + exp_params['env_name'] + '_' + exp_params['exp_id']
experiment_id = mlflow_server.new_experiment(exp_name)
# Out:
# 2024/08/30 18:34:24 INFO mlflow.tracking.fluent: Experiment with name 'env_HumanMoveSimple_exp_3008_183424' does not exist. Creating a new experiment.

# %%
i = 0
for name, m in models.items():
    print(name)
    exp_params['algorithm_name'] = name
    exp_params['seed'] = int(datetime.now(TZ).strftime("%H%M%S"))

    model = 0
    if name == 'TD3':
        n_actions = env.action_space.shape[-1]
        action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
        model = m(  exp_params['training']['policy'], 
                    env,
                    #policy_kwargs=policy_kwargs,
                    learning_rate=exp_params['training']['learning_rate'],
                    buffer_size=exp_params['training']['buffer_size'],
                    learning_starts=exp_params['training']['learning_starts'],
                    batch_size=exp_params['training']['batch_size'],
                    tau=exp_params['training']['tau'],
                    gamma=exp_params['training']['gamma'],
                    verbose=exp_params['training']['verbose'],
                    action_noise=action_noise,
                    device=device,
                    )
    else:
        model = m(  exp_params['training']['policy'], 
                    env,
                    policy_kwargs=policy_kwargs,
                    learning_rate=exp_params['training']['learning_rate'],
                    buffer_size=exp_params['training']['buffer_size'],
                    learning_starts=exp_params['training']['learning_starts'],
                    batch_size=exp_params['training']['batch_size'],
                    tau=exp_params['training']['tau'],
                    gamma=exp_params['training']['gamma'],
                    verbose=exp_params['training']['verbose'],
                    device=device,
                    )

    art_loc, exp_name, run_id = mlflow_server.learn_and_fix(
                                model=model, 
                                env=HumanMoveSimpleAction(render_mode='rgb_array'),
                                run_name=name,
                                episode_count = exp_params['training']['episode_count'],
                                parameters=exp_params,
                                experiment_id=experiment_id,
                                checkpoint_interval=exp_params['validation']['validate_agent_every_n_eps'],
                                log_interval=exp_params['validation']['log_interval'])

    mlflow_path[name] = f'{art_loc}/{run_id}/artifacts/{exp_name}/sb3/model.zip'

    i = i + 1
# Out:
# DDPG
# Output()
# r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path
# 'env_HumanMoveSimple_exp_3008_183424\600' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# Saving video to
# r:\Scool\Otus\HomeWork\otus_final\source\env_HumanMoveSimple_exp_3008_183424\600\agent-step-0-to-step-300.mp4
# Moviepy - Building video
# r:\Scool\Otus\HomeWork\otus_final\source\env_HumanMoveSimple_exp_3008_183424\600\agent-step-0-to-step-300.mp4.
# Moviepy - Writing video
# r:\Scool\Otus\HomeWork\otus_final\source\env_HumanMoveSimple_exp_3008_183424\600\agent-step-0-to-step-300.mp4
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]
# t:   0%|          | 0/301 [00:00<?, ?it/s, now=None]Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\formatters.py", line 226, in
# catch_format_error
#     r = method(self, *args, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\formatters.py", line 913, in __call__
#     if self.enabled:
#        ^^^^^^^^^^^^
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\traitlets\traitlets.py", line 687, in __get__
#     return t.cast(G, self.get(obj, cls))  # the G should encode the Optional
#                      ^^^^^^^^^^^^^^^^^^
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\traitlets\traitlets.py", line 666, in get
#     return t.cast(G, value)
#            ^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# During handling of the above exception, another exception occurred:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Traceback (most recent call last):
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py", line 53, in flush
#     self.__console.print(output)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 1673, in print
#     with self:
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 865, in __exit__
#     self._exit_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 823, in _exit_buffer
#     self._check_buffer()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py", line 2007, in _check_buffer
#     display(self._buffer, self._render_buffer(self._buffer[:]))
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py", line 91, in display
#     ipython_display(jupyter_renderable)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 305, in
# display
#     publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py", line 93, in
# publish_display_data
#     display_pub.publish(
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 103, in publish
#     self._flush_streams()
#   File "r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py", line 67, in _flush_streams
#     sys.stderr.flush()
# ...
# --> 471 for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
#     472     frame = self.get_frame(t)
#     473     if (dtype is not None) and (frame.dtype != dtype):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\proglog\proglog.py:190, in ProgressBarLogger.iter_bar(self, bar_prefix, **kw)
#     188 bar = bar_prefix + bar
#     189 if hasattr(iterable, '__len__'):
# --> 190     self(**{bar + '__total': len(iterable)})
#     192 def new_iterable():
#     193     last_time = time.time()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\proglog\proglog.py:255, in ProgressBarLogger.__call__(self, **kw)
#     253             self.log_indent += self.bar_indent
#     254         self.bars[bar][attr] = value
# --> 255         self.bars_callback(bar, attr, value, old_value)
#     256 self.state.update(kw)
#     257 self.callback(**kw)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\proglog\proglog.py:330, in TqdmProgressBarLogger.bars_callback(self, bar, attr, value, old_value)
#     328 def bars_callback(self, bar, attr, value, old_value):
#     329     if (bar not in self.tqdm_bars) or (self.tqdm_bars[bar] is None):
# --> 330         self.new_tqdm_bar(bar)
#     331     if attr == 'index':
#     332         if value >= old_value:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\proglog\proglog.py:316, in TqdmProgressBarLogger.new_tqdm_bar(self, bar)
#     314     self.close_tqdm_bar(bar)
#     315 infos = self.bars[bar]
# --> 316 self.tqdm_bars[bar] = self.tqdm(
#     317    total=infos['total'],
#     318    desc=infos['title'],
#     319    postfix=dict(now=troncate_string(str(infos['message']))),
#     320    leave=self.leave_bars
#     321 )
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\tqdm\std.py:1095, in tqdm.__init__(self, iterable, desc, total, leave, file, ncols, mininterval, maxinterval, miniters, ascii, disable, unit, unit_scale, dynamic_ncols, smoothing, bar_format, initial, position, postfix, unit_divisor, write_bytes, lock_args, nrows, colour, delay, gui, **kwargs)
#    1093     self.sp = self.status_printer(self.fp)
#    1094     if delay <= 0:
# -> 1095         self.refresh(lock_args=self.lock_args)
#    1097 # Init the time counter
#    1098 self.last_print_t = self._time()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\tqdm\std.py:1344, in tqdm.refresh(self, nolock, lock_args)
#    1342     else:
#    1343         self._lock.acquire()
# -> 1344 self.display()
#    1345 if not nolock:
#    1346     self._lock.release()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\tqdm\std.py:1492, in tqdm.display(self, msg, pos)
#    1490 if pos:
#    1491     self.moveto(pos)
# -> 1492 self.sp(self.__str__() if msg is None else msg)
#    1493 if pos:
#    1494     self.moveto(-pos)
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\tqdm\std.py:347, in tqdm.status_printer.<locals>.print_status(s)
#     345 def print_status(s):
#     346     len_s = disp_len(s)
# --> 347     fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     348     last_len[0] = len_s
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\tqdm\std.py:341, in tqdm.status_printer.<locals>.fp_write(s)
#     339 def fp_write(s):
#     340     fp.write(str(s))
# --> 341     fp_flush()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\tqdm\utils.py:127, in DisableOnWriteError.disable_on_exception.<locals>.inner(*args, **kwargs)
#     125 def inner(*args, **kwargs):
#     126     try:
# --> 127         return func(*args, **kwargs)
#     128     except OSError as e:
#     129         if e.errno != 5:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:1673, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1671     crop = False
#    1672 render_hooks = self._render_hooks[:]
# -> 1673 with self:
#    1674     renderables = self._collect_renderables(
#    1675         objects,
#    1676         sep,
#    (...)
#    1681         highlight=highlight,
#    1682     )
#    1683     for hook in render_hooks:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:865, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     864     """Exit buffer context."""
# --> 865     self._exit_buffer()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:823, in Console._exit_buffer(self)
#     821 """Leave buffer context, and render content if required."""
#     822 self._buffer_index -= 1
# --> 823 self._check_buffer()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:2007, in Console._check_buffer(self)
#    2004 if self.is_jupyter:  # pragma: no cover
#    2005     from .jupyter import display
# -> 2007     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2008     del self._buffer[:]
#    2009 else:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py:305, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     302         if metadata:
#     303             # kwarg-specified metadata gets precedence
#     304             _merge(md_dict, metadata)
# --> 305         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     306 if display_id:
#     307     return DisplayHandle(display_id)
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py:93, in publish_display_data(data, metadata, source, transient, **kwargs)
#      90 if transient:
#      91     kwargs['transient'] = transient
# ---> 93 display_pub.publish(
#      94     data=data,
#      95     metadata=metadata,
#      96     **kwargs
#      97 )
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)
#      86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)
#     101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py:67, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
#      66 sys.stdout.flush()
# ---> 67 sys.stderr.flush()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:1673, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1671     crop = False
#    1672 render_hooks = self._render_hooks[:]
# -> 1673 with self:
#    1674     renderables = self._collect_renderables(
#    1675         objects,
#    1676         sep,
#    (...)
#    1681         highlight=highlight,
#    1682     )
#    1683     for hook in render_hooks:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:865, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     864     """Exit buffer context."""
# --> 865     self._exit_buffer()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:823, in Console._exit_buffer(self)
#     821 """Leave buffer context, and render content if required."""
#     822 self._buffer_index -= 1
# --> 823 self._check_buffer()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:2007, in Console._check_buffer(self)
#    2004 if self.is_jupyter:  # pragma: no cover
#    2005     from .jupyter import display
# -> 2007     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2008     del self._buffer[:]
#    2009 else:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py:305, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     302         if metadata:
#     303             # kwarg-specified metadata gets precedence
#     304             _merge(md_dict, metadata)
# --> 305         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     306 if display_id:
#     307     return DisplayHandle(display_id)
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py:93, in publish_display_data(data, metadata, source, transient, **kwargs)
#      90 if transient:
#      91     kwargs['transient'] = transient
# ---> 93 display_pub.publish(
#      94     data=data,
#      95     metadata=metadata,
#      96     **kwargs
#      97 )
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)
#      86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)
#     101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py:67, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
#      66 sys.stdout.flush()
# ---> 67 sys.stderr.flush()
#
#     [... skipping similar frames: Console.__exit__ at line 865 (291 times), Console._check_buffer at line 2007 (291 times), Console._exit_buffer at line 823 (291 times), FileProxy.flush at line 53 (291 times), Console.print at line 1673 (291 times), ZMQDisplayPublisher._flush_streams at line 67 (290 times), display at line 91 (290 times), display at line 305 (290 times), ZMQDisplayPublisher.publish at line 103 (290 times), publish_display_data at line 93 (290 times)]
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py:305, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     302         if metadata:
#     303             # kwarg-specified metadata gets precedence
#     304             _merge(md_dict, metadata)
# --> 305         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     306 if display_id:
#     307     return DisplayHandle(display_id)
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\IPython\core\display_functions.py:93, in publish_display_data(data, metadata, source, transient, **kwargs)
#      90 if transient:
#      91     kwargs['transient'] = transient
# ---> 93 display_pub.publish(
#      94     data=data,
#      95     metadata=metadata,
#      96     **kwargs
#      97 )
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)
#      86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)
#     101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\ipykernel\zmqshell.py:67, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
#      66 sys.stdout.flush()
# ---> 67 sys.stderr.flush()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:1673, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1671     crop = False
#    1672 render_hooks = self._render_hooks[:]
# -> 1673 with self:
#    1674     renderables = self._collect_renderables(
#    1675         objects,
#    1676         sep,
#    (...)
#    1681         highlight=highlight,
#    1682     )
#    1683     for hook in render_hooks:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:865, in Console.__exit__(self, exc_type, exc_value, traceback)
#     863 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     864     """Exit buffer context."""
# --> 865     self._exit_buffer()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:823, in Console._exit_buffer(self)
#     821 """Leave buffer context, and render content if required."""
#     822 self._buffer_index -= 1
# --> 823 self._check_buffer()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\console.py:2007, in Console._check_buffer(self)
#    2004 if self.is_jupyter:  # pragma: no cover
#    2005     from .jupyter import display
# -> 2007     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2008     del self._buffer[:]
#    2009 else:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py:86, in display(segments, text)
#      84 def display(segments: Iterable[Segment], text: str) -> None:
#      85     """Render segments to Jupyter."""
# ---> 86     html = _render_segments(segments)
#      87     jupyter_renderable = JupyterRenderable(html, text)
#      88     try:
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\jupyter.py:67, in _render_segments(segments)
#      65 append_fragment = fragments.append
#      66 theme = DEFAULT_TERMINAL_THEME
# ---> 67 for text, style, control in Segment.simplify(segments):
#      68     if control:
#      69         continue
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\rich\segment.py:526, in Segment.simplify(cls, segments)
#     524 _Segment = Segment
#     525 for segment in iter_segments:
# --> 526     if last_segment.style == segment.style and not segment.control:
#     527         last_segment = _Segment(
#     528             last_segment.text + segment.text, last_segment.style
#     529         )
#     530     else:
#
# RecursionError: maximum recursion depth exceeded

# %%
mlflow_path
# Out:
# {'DDPG': 'mlflow-artifacts:/54/0db1a7bd6633464b9bc93dda987837a8/artifacts/env_HumanMoveSimple_exp_2508_115957/sb3/model.zip',
#  'SAC': 'mlflow-artifacts:/54/deb23750b2e04dad878e96c9e0eb6524/artifacts/env_HumanMoveSimple_exp_2508_115957/sb3/model.zip',
#  'TD3': 'mlflow-artifacts:/54/2cf8be691f4a4c869cd2b78e383ff68d/artifacts/env_HumanMoveSimple_exp_2508_115957/sb3/model.zip'}

# %%
m_name = 'DDPG'
local_path = f'/sb3/{m_name}/'
sac_path = mlflow_path.get(m_name)
print(sac_path)
mlflow_server.load_artifact(sac_path, local_path)
read_model = models[m_name].load(local_path + 'model.zip')
# Out:
# mlflow-artifacts:/54/0db1a7bd6633464b9bc93dda987837a8/artifacts/env_HumanMoveSimple_exp_2508_115957/sb3/model.zip
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
seed = int(datetime.now(TZ).strftime("%H%M%S"))
env_render = HumanMoveSimpleAction(render_mode = 'human', seed=seed)
total_reward = 0.
step_reward = []
observation, _ = env_render.reset()
terminated = False
truncated = False
while not terminated and not truncated:
    action, _ = read_model.predict(observation)
    observation, reward, terminated, truncated, _ = env_render.step(action)
    total_reward += reward
    step_reward.append(reward)

total_reward
# Out:
# -201.229332863059

# %%
env_render.close()
