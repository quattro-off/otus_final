# %%
import numpy as np
from pytz import timezone
from datetime import datetime

TZ = timezone('Europe/Moscow')

import sys
import os


sys.path.append(os.path.abspath('./'))

from env_move_sector import HumanMoveSectorAction

# %%
seed = int( datetime.now(TZ).strftime("%H%M%S") )
print(seed)

env = HumanMoveSectorAction(render_mode = 'human',
                            continuous=True, 
                            target_point_rand=False, 
                            object_ignore=False, 
                            seed=seed)

total_reward = 0.
step_reward = []

observation, info = env.reset(seed=seed)
# course move, speed


for tick in range(800):

    #action = env.teach_action()
    action = np.array([0,0,1])

    observation, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        observation, info = env.reset()
        step_reward.append(reward)
        total_reward += reward
        print('BREAK')
        break
    
    step_reward.append(reward)
    total_reward += reward

print(len(step_reward))
print(total_reward)
# Out:
# 172653
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.468347985889825
# Info: Stoper Object: tree_17 dist 4.169858405123623
# Info: Stoper Object: tree_17 dist 4.051777052981711
# Info: Stoper Object: tree_17 dist 4.476120074565144
# Info: Stoper Object: tree_17 dist 5.468347985889825
# Info: Stoper Object: tree_17 dist 4.169858405123623
# Info: Stoper Object: tree_17 dist 4.051777052981711
# Info: Stoper Object: tree_17 dist 4.476120074565144
# Info: Stoper Object: tree_17 dist 5.468347985889825
# Info: Stoper Object: tree_17 dist 4.169858405123623
# Info: Stoper Object: tree_17 dist 4.051777052981711
# Info: Stoper Object: tree_17 dist 4.476120074565144
# Info: Stoper Object: tree_17 dist 5.468347985889825
# Info: Stoper Object: tree_17 dist 4.169858405123623
# Info: Stoper Object: tree_17 dist 4.051777052981711
# Info: Stoper Object: tree_17 dist 4.476120074565144
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.517520511478045
# Info: Stoper Object: tree_17 dist 4.19003604024783
# Info: Stoper Object: tree_17 dist 4.0624287546817035
# Info: Stoper Object: tree_17 dist 4.508498754765346
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# Info: Stoper Object: tree_17 dist 5.3715479980350205
# Info: Stoper Object: tree_17 dist 4.125598966931258
# Info: Stoper Object: tree_17 dist 4.036204075570012
# Info: Stoper Object: tree_17 dist 4.478249922523047
# BREAK
# 417
# -1.4160000000000004

# %%
step_reward

# %%
env.close()

# %%
from env_move_sector import HumanMoveSectorAction
from stable_baselines3 import DQN, SAC
from typing import Any, Dict, Tuple, Union
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.logger import Logger, Video
from moviepy.editor import ImageSequenceClip
import torch
import numpy as np

DQN_path = "../sb3_SAC/"

tmp_path = DQN_path + "model_2"

seed = int( datetime.now(TZ).strftime("%H%M%S") )
env = HumanMoveSectorAction(render_mode = 'rgb_array', continuous=True, seed=seed)
model = SAC.load(tmp_path, env)

logger = Logger(folder = DQN_path, output_formats=["mp4"])

#Video
screens = []

def grab_screens(_locals: Dict[str, Any], _globals: Dict[str, Any]) -> None:
    """
    Renders the environment in its current state, recording the screen in the captured `screens` list

    :param _locals: A dictionary containing all local variables of the callback's scope
    :param _globals: A dictionary containing all global variables of the callback's scope
    """
    screen = env.render()
    screens.append(screen)

evaluate_policy(
    model,
    env,
    callback=grab_screens,
    n_eval_episodes=1,
    deterministic=True,
)

#logger.record(
#    "video",
#    Video(torch.from_numpy(np.asarray([screens])), fps=30),
#    exclude=("stdout", "log", "json", "csv"),
#)

# Generate a sequence of frames
clip = ImageSequenceClip(screens[:-1], fps=30)
clip.write_videofile('output.mp4')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 33
#      30     screen = env.render()
#      31     screens.append(screen)
# ---> 33 evaluate_policy(
#      34     model,
#      35     env,
#      36     callback=grab_screens,
#      37     n_eval_episodes=1,
#      38     deterministic=True,
#      39 )
#      41 #logger.record(
#      42 #    "video",
#      43 #    Video(torch.from_numpy(np.asarray([screens])), fps=30),
#    (...)
#      46
#      47 # Generate a sequence of frames
#      48 clip = ImageSequenceClip(screens[:-1], fps=30)
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\stable_baselines3\common\evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File r:\Scool\Anaconda\envs\rl_conda_311\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File r:\Scool\Otus\HomeWork\otus_final\source\env\env_move_sector.py:225, in HumanMoveSectorAction.step(self, action)
#     222     return self._get_render(True), step_reward, terminated, truncated, info
#     223 else:
# --> 225     observation, step_reward, terminated, truncated, info = super().step(action)
#     227     for k in self.sectors.keys():
#     228         self.sectors[k]  = [0,0.,0.,1.,0.]
#
# File r:\Scool\Otus\HomeWork\otus_final\source\env\env_simple_move.py:248, in HumanMoveSimpleAction.step(self, action)
#     245     set_speed_forward = self._clamp(set_speed_forward, -self.speed_k, self.speed_k)
#     246     set_speed_right = self._clamp(set_speed_right, -self.speed_k, self.speed_k)
# --> 248 self.simple_move(set_angle_speed, set_speed_forward, set_speed_right)
#     249 step_reward, terminated, truncated = self.calc_step_reward(set_angle_speed, set_speed_forward, set_speed_right)
#     251 # вознаграждение за правильное решение
#
# File r:\Scool\Otus\HomeWork\otus_final\source\env\env_move_sector.py:271, in HumanMoveSectorAction.simple_move(self, set_angle_dir, set_speed_forward, set_speed_right)
#     269 if dist < object['radius'] + 1:
#     270     vec_dist = vec_dist / vec_dist.rho
# --> 271     cos_to_tree = vec_dist @ self.dir_move
#     272     if cos_to_tree > 0:
#     273         id = object['id']
#
# AttributeError: 'HumanMoveSectorAction' object has no attribute 'dir_move'
